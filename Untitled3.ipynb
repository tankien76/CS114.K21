# %% [markdown]
# <a href="https://colab.research.google.com/github/tankien76/CS114.K21/blob/master/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Run this cell and select the kaggle.json file downloaded
# from the Kaggle account settings page.
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-daaaefd3-8d5b-42ba-96be-3a45cdfa3368" name="files[]" multiple disabled />
#      <output id="result-daaaefd3-8d5b-42ba-96be-3a45cdfa3368">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"minhdoanxuan","key":"381104af01a5bb8a20ac1f5e0adf5431"}'}

# %%
# Let's make sure the kaggle.json file is present.
# !ls -lha kaggle.json
# Out:
# -rw-r--r-- 1 root root 68 May 28 04:58 kaggle.json

# %%
# Next, install the Kaggle API client.
# !pip install -q kaggle

# %%
# The Kaggle API client expects this file to be in ~/.kaggle,
# so move it there.
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# This permissions change avoids a warning on Kaggle tool startup.
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# List available datasets.
# https://github.com/Kaggle/kaggle-api
# !kaggle datasets list -s face
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.6 / client 1.5.4)
# ref                                                          title                                            size  lastUpdated          downloadCount
# -----------------------------------------------------------  ----------------------------------------------  -----  -------------------  -------------
# atulanandjha/lfwpeople                                       LFW - People (Face Recognition)                 232MB  2019-11-15 19:45:43           2404
# dataturks/face-detection-in-images                           Face Detection in Images                         55KB  2018-07-12 09:34:14           5867
# splcher/animefacedataset                                     Anime Face Dataset                              395MB  2019-10-13 16:33:20           1080
# selfishgene/youtube-faces-with-facial-keypoints              YouTube Faces With Facial Keypoints                0B  2020-05-25 22:53:33           4259
# ciplab/real-and-fake-face-detection                          Real and Fake Face Detection                    431MB  2019-01-14 14:54:52           2993
# timesler/facenet-pytorch-vggface2                            facenet pytorch vggface2                        112MB  2020-03-12 03:27:00           1111
# berkeleyearth/climate-change-earth-surface-temperature-data  Climate Change: Earth Surface Temperature Data   85MB  2017-05-01 17:29:10          50415
# kostastokis/simpsons-faces                                   Simpsons Faces                                  442MB  2018-09-28 17:38:04           3442
# drgilermo/face-images-with-marked-landmark-points            Face Images with Marked Landmark Points         105MB  2017-09-19 18:39:17           3188
# jessicali9530/celeba-dataset                                 CelebFaces Attributes (CelebA) Dataset            1GB  2018-06-01 20:08:48          29757
# gpreda/haar-cascades-for-face-detection                      Haar Cascades for Face Detection                  1MB  2019-12-21 21:09:41            534
# greatgamedota/ffhq-face-data-set                             FFHQ Face Data Set                                2GB  2019-10-12 22:12:09            142
# jessicali9530/lfw-dataset                                    Labelled Faces in the Wild (LFW) Dataset        112MB  2018-05-17 19:57:27           4267
# soumikrakshit/anime-faces                                    Anime Faces                                     441MB  2019-05-16 10:38:47           1859
# facebook/facebook-v-results                                  Facebook V Results: Predicting Check Ins          3GB  2019-11-17 21:51:39           2767
# humananalog/blazeface-pytorch                                BlazeFace PyTorch                               378KB  2020-01-12 21:24:08           1655
# mchirico/cheltenham-s-facebook-group                         Cheltenham's Facebook Groups                       0B  2018-04-02 18:55:36           1463
# madislemsalu/facebook-ad-campaign                            Facebook Ad Campaign                             21KB  2019-01-11 17:23:56           2314
# olgabelitskaya/yale-face-database                            Yale Face Database                               12MB  2018-09-05 09:54:51           1970
# mrisdal/2016-us-presidential-debates                         2016 US Presidential Debates                    120KB  2016-10-24 03:13:26           3855
